# %% [markdown]
# <a href="https://colab.research.google.com/github/younghoonNa/ML/blob/main/%EC%A7%91%EA%B0%92%EC%98%88%EC%B8%A1_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **한림대 파이썬을 활용한 데이터분석 방학집중교육 심화과정 최종 프로젝트**
#
# ## 프로젝트 소개
# 본 프로젝트는 주택 가격에 영향을 줄 수 있는 79개의 특성들을 이용하여 주택 가격을 예측하는 것이 목표입니다.
#
# ## 파일 구성
#  - **train.csv**: 학습 데이터
#  - **test.csv**: 평가 데이터
#  - **submission.csv**: 제출 데이터
#
# ## 특성 설명
#  - `SalePrice`: 부동산의 판매 가격 (달러). **레이블 (종속변수, 타겟변수)**.
#  - `MSSubClass` : 건물 등급
#  - `MSZoning` : 일반 구역 분류
#  - `LotFrontage` : 부동산에 연결된 거리의 선형 피트
#  - `LotArea` : 평방 피트 단위의 부지 크기
#  - `Street` : 도로 유형
#  - `Alley` : 골목 유형
#  - `LotShape` : 부지유형
#  - `LandContour` : 부동산의 평탄도
#  - `Utilities` : 사용 가능한 유틸리티 유형
#  - `LotConfig` : 부지 구성
#  - `LandSlope` : 부동산의 경사
#  - `Neighborhood` : 인근유형. 물리적 위치
#  - `Condition1` : 주요 도로 또는 철도와의 근접성
#  - `Condition2` : 주요 도로 또는 철도와의 근접성 (2번째 조건이 존재하는 경우)
#  - `BldgType` : 주거 유형
#  - `HouseStyle` : 주거 스타일
#  - `OverallQual` : 전체 재료 및 마감 품질
#  - `OverallCond` : 전체 상태 등급
#  - `YearBuilt` : 준공일준공일
#  - `YearRemodAdd` : 리모델링 날짜
#  - `RoofStyle` : 지붕 유형
#  - `RoofMatl` : 지붕 재료
#  - `Exterior1st` : 주택주택 외장재
#  - `Exterior2nd` : 주택 외장재 (하나 이상인 경우)
#  - `MasVnrType` : 벽돌 베니어 유형
#  - `MasVnrArea` : 벽돌 베니어 영역 (평방 피트)
#  - `ExterQual` : 외장재 품질
#  - `ExterCond` : 외장재의 현황
#  - `Foundation` : 기초 유형
#  - `BsmtQual` : 지하 높이
#  - `BsmtCond` : 지하실 일반 상태
#  - `BsmtExposure` : 워크 아웃 또는 정원 수준의 지하 벽
#  - `BsmtFinType1` : 지하실 마감면의 품질
#  - `BsmtFinSF1` : 유형 1 완성 된 평방 피트
#  - `BsmtFinType2` : 두 번째 완성 된 영역의 품질 (있는 경우)
#  - `BsmtFinSF2` : 유형 2 완성 된 평방 피트
#  - `BsmtUnfSF` : 미완성 된 지하실 면적
#  - `TotalBsmtSF` : 지하 총 평방 피트
#  - `Heating` : 난방 유형
#  - `HeatingQC` : 난방 품질 및 상태
#  - `CentralAir` : 중앙 에어컨
#  - `Electrical` : 전기 시스템
#  - `1stFlrSF` : 1 층 평방 피트
#  - `2ndFlrSF` : 2 층 평방 피트
#  - `LowQualFinSF` : 저품질 마감 평방 피트 (모든 층)
#  - `GrLivArea` : 지상 (지상) 거실 면적 평방 피트
#  - `BsmtFullBath` : 지하 전체 욕실
#  - `BsmtHalfBath` : 지하 반 욕실
#  - `FullBath` : 등급 이상의 전체 욕실
#  - `HalfBath` : 학년 이상의 Half Bath
#  - `Bedroom` : 지하층 이상의 침실 수
#  - `Kitchen` : 주방 수
#  - `KitchenQual` : 주방 품질
#  - `TotRmsAbvGrd` : 등급 이상의 총 방 (욕실은 포함되지 않음)
#  - `Functional` : 홈 기능 등급
#  - `Fireplaces` : 벽난로 수
#  - `FireplaceQu` : 벽난로 품질
#  - `GarageType` : 차고 위치
#  - `GarageYrBlt` : 차고 건설 연도
#  - `GarageFinish` : 차고 내부 마감
#  - `GarageCars` : 차량 수용 가능 차고 크기
#  - `GarageArea` : 차고 크기 (평방 피트)
#  - `GarageQual` : 차고 품질
#  - `GarageCond` : 차고 상태
#  - `PavedDrive` : 포장 된 진입로
#  - `WoodDeckSF` : 목재 데크 면적 (평방 피트)
#  - `OpenPorchSF` : 평방 피트 단위의 오픈 현관 영역
#  - `EnclosedPorch` : 밀폐 된 현관 영역 (평방 피트)
#  - `3SsnPorch` : 3 계절 현관 면적 (평방 피트)
#  - `ScreenPorch` : 스크린 포치 면적 (평방 피트)
#  - `PoolArea` : 수영장 면적 (평방 피트)
#  - `PoolQC` : 수영장 품질
#  - `Fence` : 울타리 품질
#  - `MiscFeature` : 다른 카테고리에서 다루지 않는 기타 기능
#  - `MiscVal` : 기타 기능의 가치 (달러)
#  - `MoSold` : 판매 월
#  - `YrSold` : 판매 연도
#  - `SaleType` : 판매 유형
#  - `SaleCondition` : 판매 조건
#
#
# ## 평가 측도
#  - **`rmsle`**: 낮을수록 좋음
#
# ## 최종 제출 안내
#  - 분석이 모두 완료된 수강생은 최종 제출을 해야 합니다.
#  - 최종 제출은
#   파일 -> 다운로드 -> .ipynb 다운로드를 통해 파일을 다운로드 받아서 매터모스트의 **이우엽 강사** 에게 DM으로 첨부해서 보내면 됩니다.

# %% [markdown]
# ## 필수 모듈

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from catboost import CatBoostRegressor, Pool
from sklearn.linear_model import HuberRegressor
from ngboost import NGBRegressor
from sklearn.linear_model import LassoLars
from catboost import CatBoostRegressor
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
# !pip install datawig
# Out:
# ...
#      |████████████████████████████████| 61 kB 45 kB/s
# ...
#      |████████████████████████████████| 7.0 MB 13.6 MB/s
# ...
#      |████████████████████████████████| 10.4 MB 34.4 MB/s
# ...
#      |████████████████████████████████| 29.6 MB 73 kB/s
# ...
#      |████████████████████████████████| 13.8 MB 33.0 MB/s
# ...
#   Created wheel for datawig: filename=datawig-0.2.0-py3-none-any.whl size=72679 sha256=41f6f6a4755eae8dc3162763e0e0e29c37d3f97a9e50df598767f2b936aceb0b
#   Stored in directory: /root/.cache/pip/wheels/23/44/aa/12cf6e868f0d71e3c4e57796330094461ade4cb3f1a3acd6c4
# Successfully built datawig
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.23.2
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2
#   Attempting uninstall: graphviz
# ...

# %%
# !pip install jaen

# %%
# !pip install ngboost

# %%
# ID@jaen.com
# ID를 문자열로 입력해주세요.
# ID = 
email = '20185124@jaen.com'

# %%
from JAEN.project import Project
pjt = Project('주택 가격 예측', 
              '한림대-파이썬을활용한-머신러닝프로젝트',        
              '1차수 A반',       
              email)

# %%
# !pip install catboost

# %% [markdown]
# ## 데이터 다운로드

# %%
# !wget -N --http-user=mysuni --http-passwd=mysuni1! http://sk.jaen.kr:8080/hl_house_prices.zip
# Out:
# --2022-02-18 07:50:58--  http://sk.jaen.kr:8080/hl_house_prices.zip
# Resolving sk.jaen.kr (sk.jaen.kr)... 49.247.134.238
# Connecting to sk.jaen.kr (sk.jaen.kr)|49.247.134.238|:8080... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Authentication required."
# Reusing existing connection to sk.jaen.kr:8080.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘hl_house_prices.zip’ not modified on server. Omitting download.

# %%
import zipfile

# 데이터 폴더
DATA_DIR = './data'

with zipfile.ZipFile("hl_house_prices.zip" , "r") as zip_ref:
    zip_ref.extractall(DATA_DIR)

# %% [markdown]
# ## Baseline

# %%
# 데이터 로드
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')
submission = pd.read_csv('./data/submission.csv')

# %%
drop_list = [
             "Utilities", 'Id', 'MiscFeature', 'Condition2', 'RoofMatl', 'Heating',
             'Fence' , 'FireplaceQu', 'PoolQC' , 'GarageYrBlt', 'Street', 'Alley', 'GarageCars'
]

# %%
train = train.drop(drop_list, axis=1)
test = test.drop(drop_list, axis=1)

# %%
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# 0          60       RL         65.0  ...        WD        Normal    208500
# 1          20       RL         80.0  ...        WD        Normal    181500
# 2          60       RL         68.0  ...        WD        Normal    223500
# 3          70       RL         60.0  ...        WD       Abnorml    140000
# 4          60       RL         84.0  ...        WD        Normal    250000
#
# [5 rows x 68 columns]

# %% [markdown]
# ### Exterior2nd 특징

# %%
train['Exterior2nd'].value_counts()
# Out:
# VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     60
# Wd Shng     38
# Stucco      26
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# Other        1
# CBlock       1
# Name: Exterior2nd, dtype: int64

# %%
train.loc[train['Exterior1st'] == 'VinylSd', 'SalePrice'].mean()
# Out:
# 213732.90097087377

# %%
train.loc[train['Exterior1st'] == 'CemntBd', 'SalePrice'].mean()
# Out:
# 231690.65573770492

# %%
train.loc[train['Exterior1st'] == 'BrkFace', 'SalePrice'].mean()
# Out:
# 194573.0

# %%
train.loc[train['Exterior1st'] == 'Stone', 'SalePrice'].mean()
# Out:
# 258500.0

# %%
train.loc[train['Exterior1st'] == 'ImStucc', 'SalePrice'].mean()
# Out:
# 262000.0

# %%
train.loc[train['Exterior1st'] == 'Plywood', 'SalePrice'].mean()
# Out:
# 175942.37962962964

# %%
train.loc[train['Exterior1st'] == 'HdBoard', 'SalePrice'].mean()
# Out:
# 163077.45045045044

# %%
train.loc[train['Exterior1st'] == 'MetalSd', 'SalePrice'].mean()
# Out:
# 149422.17727272728

# %%
train.loc[train['Exterior1st'] == 'Wd Sdng', 'SalePrice'].mean()
# Out:
# 149841.64563106795

# %%
train.loc[train['Exterior1st'] == 'WdShing', 'SalePrice'].mean()
# Out:
# 150655.07692307694

# %%
train.loc[train['Exterior1st'] == 'Stucco', 'SalePrice'].mean()
# Out:
# 162990.0

# %%
train.loc[train['Exterior1st'] == 'BrkComm', 'SalePrice'].mean()
# Out:
# 71000.0

# %%
train.loc[train['Exterior1st'] == 'AsbShng', 'SalePrice'].mean()
# Out:
# 107385.55

# %%
train.loc[train['Exterior1st'] == 'AsphShn', 'SalePrice'].mean()
# Out:
# 100000.0

# %%
train.loc[train['Exterior1st'] == 'CBlock', 'SalePrice'].mean()
# Out:
# 105000.0

# %%
Exterior_map={'VinylSd':3, 'CemntBd':3,
              'BrkFace':3, 'Stone':3, 'ImStucc':3,
              'Plywood':2,'HdBoard':2, 'WdShing':2,  'MetalSd':2, 'Wd Sdng':2, 'Stucco':2, 'Brk Cmn':2, 'Other':2,
              'AsbShng':1, 'AsphShn':1, 'CBlock':1, 
              'BrkComm':0, 'None': 0}

ex_list = [
           'Exterior1st', 'Exterior2nd', 'MasVnrType'
]

for li in ex_list:
  train[li] = train[li].map(Exterior_map)
  test[li] = test[li].map(Exterior_map)

# %% [markdown]
# ## 전처리2

# %%
train
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# 0             60       RL         65.0  ...        WD        Normal    208500
# 1             20       RL         80.0  ...        WD        Normal    181500
# 2             60       RL         68.0  ...        WD        Normal    223500
# 3             70       RL         60.0  ...        WD       Abnorml    140000
# 4             60       RL         84.0  ...        WD        Normal    250000
# ...          ...      ...          ...  ...       ...           ...       ...
# 1455          60       RL         62.0  ...        WD        Normal    175000
# 1456          20       RL         85.0  ...        WD        Normal    210000
# 1457          70       RL         66.0  ...        WD        Normal    266500
# 1458          20       RL         68.0  ...        WD        Normal    142125
# 1459          20       RL         75.0  ...        WD        Normal    147500
#
# [1460 rows x 68 columns]

# %%
mapping={'Ex':1, 'Gd':0, 'TA':-1, 'Fa':-1, 'Po':-1}

map_list = [
            'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 
            'HeatingQC', 'KitchenQual', 'GarageQual', 'GarageCond'
]

for li in map_list:
  train[li] = train[li].map(mapping)
  test[li] = test[li].map(mapping)

# %%
train['LotShape'].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
train.loc[train['LotShape'] == 'Reg', 'SalePrice' ].mean()
# Out:
# 164754.81837837838

# %%
train.loc[train['LotShape'] == 'IR1', 'SalePrice' ].mean()
# Out:
# 206101.6652892562

# %%
train.loc[train['LotShape'] == 'IR2', 'SalePrice' ].mean()
# Out:
# 239833.36585365853

# %%
train.loc[train['LotShape'] == 'IR3', 'SalePrice' ].mean()
# Out:
# 216036.5

# %%
mapping={'IR2':2, 'IR3': 1, 'IR1':1, 'Reg':0}

train['LotShape'] = train['LotShape'].map(mapping)
test['LotShape'] = test['LotShape'].map(mapping)

# %%
# 성능 더 안좋아짐.
# train['Sum Qual'] = train[["ExterQual", "KitchenQual", "OverallQual", 'BsmtQual', 'HeatingQC', 'GarageQual']].sum(axis=1)
# test['Sum Qual'] = test[["ExterQual", "KitchenQual", "OverallQual", 'BsmtQual', 'HeatingQC', 'GarageQual']].sum(axis=1)

# %%
mapping2={'FV':4, 'RL':3, 'RH':2, 'RH':2, 'C (all)':0}

map_list_2 = [
         'MSZoning'   
]

for li in map_list_2:
  train[li] = train[li].map(mapping2)
  test[li] = test[li].map(mapping2)

# %%
train['SalePrice'] = np.log1p(train['SalePrice'])

# %% [markdown]
# ## DataWig를 통한 결측치 처리

# %%
conn['LotFrontage'].sort_values(ascending = False)[:5]
# Out:
# LotFrontage     1.000000
# 1stFlrSF        0.443095
# GrLivArea       0.395176
# TotalBsmtSF     0.379298
# TotRmsAbvGrd    0.352330
# Name: LotFrontage, dtype: float64

# %%
import datawig

target_feature = "LotFrontage"

imputer = datawig.SimpleImputer(input_columns=['1stFlrSF', 'LotArea', 'GrLivArea', 'TotalBsmtSF'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
conn = train.corr()

# %%
conn['MasVnrType'].sort_values(ascending = False)[:6]
# Out:
# MasVnrType     1.000000
# MasVnrArea     0.687899
# YearBuilt      0.432100
# OverallQual    0.407557
# SalePrice      0.402954
# ExterQual      0.352062
# Name: MasVnrType, dtype: float64

# %%
import datawig

target_feature = "MasVnrType"

imputer = datawig.SimpleImputer(input_columns=['MasVnrArea', 'YearBuilt', 'OverallQual'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
conn['MasVnrArea'].sort_values(ascending = False)[:5]
# Out:
# MasVnrArea     1.000000
# MasVnrType     0.687899
# SalePrice      0.430809
# OverallQual    0.411876
# GrLivArea      0.390857
# Name: MasVnrArea, dtype: float64

# %%
train['MasVnrArea'].isna().sum()
# Out:
# 8

# %%
import datawig

target_feature = "MasVnrArea"

imputer = datawig.SimpleImputer(input_columns=['MasVnrType', 'OverallQual', 'GrLivArea'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
conn['BsmtQual'].sort_values(ascending = False)[:5]
# Out:
# BsmtQual       1.000000
# YearBuilt      0.709987
# OverallQual    0.671269
# ExterQual      0.660312
# SalePrice      0.654133
# Name: BsmtQual, dtype: float64

# %%
import datawig

target_feature = "BsmtQual"

imputer = datawig.SimpleImputer(input_columns=['YearBuilt', 'OverallQual', 'ExterQual'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
conn['BsmtCond'].sort_values(ascending = False)[:5],  conn['BsmtCond'].sort_values()[:5]
# Out:
# (BsmtCond       1.000000
#  ExterCond      0.161500
#  SalePrice      0.101907
#  BsmtQual       0.098485
#  OverallQual    0.092883
#  Name: BsmtCond, dtype: float64,
#  YrSold          -0.105662
#  KitchenAbvGr    -0.040265
#  EnclosedPorch   -0.034477
#  LowQualFinSF    -0.026494
#  3SsnPorch       -0.025168
#  Name: BsmtCond, dtype: float64)

# %%
import datawig

target_feature = "BsmtCond"

imputer = datawig.SimpleImputer(input_columns=['ExterCond', 'BsmtQual', 'YrSold'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
train['BsmtExposure'].value_counts()
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64

# %%
train['SalePrice'] = np.expm1(train['SalePrice'])

# %%
print(train.loc[train['BsmtExposure'] == 'No', 'SalePrice'].mean())
print(train.loc[train['BsmtExposure'] == 'Av', 'SalePrice'].mean())
print(train.loc[train['BsmtExposure'] == 'Gd', 'SalePrice'].mean())
print(train.loc[train['BsmtExposure'] == 'Mn', 'SalePrice'].mean())
# Out:
# 165652.29590766
# 206643.42081447964
# 257689.80597014926
# 192789.65789473685

# %%
mapping_bsmt={'Gd':2, 'Av':1, 'Mn':1, 'No':0}

map_list = [
            'BsmtExposure'
]

for li in map_list:
  train[li] = train[li].map(mapping_bsmt)
  test[li] = test[li].map(mapping_bsmt)

# %%
conn = train.corr()

# %%
conn['BsmtExposure'].sort_values(ascending = False)[:5],  conn['BsmtExposure'].sort_values()[:5]
# Out:
# (BsmtExposure    1.000000
#  SalePrice       0.355997
#  BsmtFinSF1      0.349828
#  TotalBsmtSF     0.324115
#  BsmtFullBath    0.317442
#  Name: BsmtExposure, dtype: float64,
#  BedroomAbvGr    -0.109419
#  2ndFlrSF        -0.107874
#  BsmtUnfSF       -0.098802
#  EnclosedPorch   -0.084651
#  OverallCond     -0.065730
#  Name: BsmtExposure, dtype: float64)

# %%
import datawig

target_feature = "BsmtExposure"

imputer = datawig.SimpleImputer(input_columns=['BsmtFinSF1', 'TotalBsmtSF', 'BsmtFullBath'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
train['BsmtFinType1'].value_counts()
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
train['BsmtFinType1'].value_counts()
print(train.loc[train['BsmtFinType1'] == 'Unf', 'SalePrice'].mean())
print(train.loc[train['BsmtFinType1'] == 'GLQ', 'SalePrice'].mean())
print(train.loc[train['BsmtFinType1'] == 'ALQ', 'SalePrice'].mean())
print(train.loc[train['BsmtFinType1'] == 'BLQ', 'SalePrice'].mean())
print(train.loc[train['BsmtFinType1'] == 'Rec', 'SalePrice'].mean())
print(train.loc[train['BsmtFinType1'] == 'LwQ', 'SalePrice'].mean())
# Out:
# 170670.57674418605
# 235413.72009569377
# 161573.06818181818
# 149493.6554054054
# 146889.24812030076
# 151852.7027027027

# %%
mapping_bsmt_fin={'Unf':1, 'GLQ':2, 'ALQ':1, 'BLQ':1, 'Rec':1, 'LwQ':1, 'RFn':2, 'Fin':3}

map_list = [
            'BsmtFinType1','BsmtFinType2', 'GarageFinish'
]

for li in map_list:
  train[li] = train[li].map(mapping_bsmt_fin)
  test[li] = test[li].map(mapping_bsmt_fin)

# %%
conn = train.corr()

# %%
conn['BsmtFinType1'].sort_values(ascending = False)[:5],  conn['BsmtFinType1'].sort_values()[:5]
# Out:
# (BsmtFinType1    1.000000
#  BsmtFinSF1      0.490011
#  BsmtQual        0.485723
#  YearBuilt       0.477177
#  BsmtFullBath    0.443125
#  Name: BsmtFinType1, dtype: float64,
#  BsmtUnfSF       -0.185862
#  OverallCond     -0.169375
#  BedroomAbvGr    -0.142003
#  EnclosedPorch   -0.137007
#  BsmtFinSF2      -0.111174
#  Name: BsmtFinType1, dtype: float64)

# %%
import datawig

target_feature = "BsmtFinType1"

imputer = datawig.SimpleImputer(input_columns=['BsmtFinSF1', 'BsmtQual', 'YearBuilt', 'BsmtFullBath'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
conn = train.corr()

# %%
conn['BsmtFinType2'].sort_values(ascending = False)[:5],  conn['BsmtFinType2'].sort_values()[:5]
# Out:
# (BsmtFinType2    1.000000
#  BsmtFinSF2      0.373900
#  BsmtFullBath    0.080635
#  LotShape        0.057549
#  MSSubClass      0.054741
#  Name: BsmtFinType2, dtype: float64,
#  BsmtUnfSF      -0.079218
#  BedroomAbvGr   -0.071612
#  MasVnrType     -0.069437
#  BsmtFinType1   -0.064231
#  MasVnrArea     -0.051465
#  Name: BsmtFinType2, dtype: float64)

# %%
import datawig

target_feature = "BsmtFinType2"

imputer = datawig.SimpleImputer(input_columns=['BsmtFinSF2'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
print(train['MSZoning'].value_counts())
print(train.loc[train['MSZoning'] == 3, 'SalePrice'].mean())
print(train.loc[train['MSZoning'] == 4, 'SalePrice'].mean())
print(train.loc[train['MSZoning'] == 2, 'SalePrice'].mean())
print(train.loc[train['MSZoning'] == 0, 'SalePrice'].mean())
# Out:
# 3.0    1151
# 4.0      65
# 2.0      16
# 0.0      10
# Name: MSZoning, dtype: int64
# 191004.99478714162
# 214014.06153846157
# 131558.375
# 74527.99999999999

# %%
conn['MSZoning'].sort_values(ascending = False)[:5],  conn['MSZoning'].sort_values()[:5]
# Out:
# (MSZoning        1.000000
#  YearBuilt       0.316029
#  YearRemodAdd    0.248377
#  OverallQual     0.233118
#  ExterQual       0.198798
#  Name: MSZoning, dtype: float64,
#  EnclosedPorch   -0.146731
#  LowQualFinSF    -0.098035
#  KitchenAbvGr    -0.096344
#  LotFrontage     -0.073388
#  MoSold          -0.050661
#  Name: MSZoning, dtype: float64)

# %%
import datawig

target_feature = "MSZoning"

imputer = datawig.SimpleImputer(input_columns=['YearBuilt', 'YearRemodAdd', 'OverallQual', 'ExterQual'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
print(train['Electrical'].value_counts())
print(train.loc[train['Electrical'] == "SBrkr", 'SalePrice'].mean())
print(train.loc[train['Electrical'] == "FuseA", 'SalePrice'].mean())
print(train.loc[train['Electrical'] == "FuseF", 'SalePrice'].mean())
print(train.loc[train['Electrical'] == 'FuseP', 'SalePrice'].mean())
print(train.loc[train['Electrical'] == 'Mix', 'SalePrice'].mean())
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64
# 186825.1131934033
# 122196.89361702128
# 107675.44444444444
# 97333.33333333331
# 67000.0

# %%
mapping_ec ={'SBrkr':4, 'FuseA':3, 'FuseF':2, 'FuseP': 1, 'Mix':0}

train['Electrical'] = train['Electrical'].map(mapping_ec)
test['Electrical'] = test['Electrical'].map(mapping_ec)

# %%
conn = train.corr()

# %%
conn['Electrical'].sort_values(ascending = False)[:5],  conn['Electrical'].sort_values()[:5]
# Out:
# (Electrical      1.000000
#  YearRemodAdd    0.339480
#  YearBuilt       0.322119
#  OverallQual     0.242558
#  SalePrice       0.233590
#  Name: Electrical, dtype: float64,
#  KitchenAbvGr    -0.169440
#  EnclosedPorch   -0.144073
#  LowQualFinSF    -0.020088
#  MoSold          -0.001944
#  BsmtUnfSF       -0.001105
#  Name: Electrical, dtype: float64)

# %%
import datawig

target_feature = "Electrical"

imputer = datawig.SimpleImputer(input_columns=['YearRemodAdd', 'YearBuilt', 'OverallQual'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1478/2485703235.py in <module>
#      18
#      19 null_train = test[test[target_feature].isnull()]
# ---> 20 null_imputed = imputer.predict(null_train)
#      21 imputed_train = pd.DataFrame(null_imputed)
#      22
#
# /usr/local/lib/python3.7/dist-packages/datawig/simple_imputer.py in predict(self, data_frame, precision_threshold, imputation_suffix, score_suffix, inplace)
#     418         """
#     419         imputations = self.imputer.predict(data_frame, precision_threshold, imputation_suffix,
# --> 420                                            score_suffix, inplace=inplace)
#     421
#     422         return imputations
#
# /usr/local/lib/python3.7/dist-packages/datawig/imputer.py in predict(self, data_frame, precision_threshold, imputation_suffix, score_suffix, inplace)
# ...

# %% [markdown]
# ## Electrical은 test데이터에 결측치 없음 오류나므로 다시 밑에서 한번에 재실행

# %%
print(train['GarageType'].value_counts())
print(train.loc[train['GarageType'] == "Attchd", 'SalePrice'].mean())
print(train.loc[train['GarageType'] == "Detchd", 'SalePrice'].mean())
print(train.loc[train['GarageType'] == "BuiltIn", 'SalePrice'].mean())
print(train.loc[train['GarageType'] == 'Basment', 'SalePrice'].mean())
print(train.loc[train['GarageType'] == 'CarPort', 'SalePrice'].mean())
print(train.loc[train['GarageType'] == '2Types', 'SalePrice'].mean())
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
# 202892.65632183908
# 134091.16279069768
# 254751.73863636365
# 160570.68421052632
# 109962.11111111114
# 151283.3333333333

# %%
mapping_gt ={'Attchd':4, 'Detchd':3, 'BuiltIn':5, 'Basment': 4, 'CarPort':1, '2Types':3}

train['GarageType'] = train['GarageType'].map(mapping_gt)
test['GarageType'] = test['GarageType'].map(mapping_gt)

# %%
conn = train.corr()

# %%
conn['GarageType'].sort_values(ascending = False)[:5],  conn['GarageType'].sort_values()[:5]
# Out:
# (GarageType      1.000000
#  GarageFinish    0.546514
#  YearBuilt       0.536431
#  SalePrice       0.438261
#  OverallQual     0.436803
#  Name: GarageType, dtype: float64,
#  KitchenAbvGr    -0.195511
#  EnclosedPorch   -0.158557
#  OverallCond     -0.155625
#  LowQualFinSF    -0.111508
#  ExterCond       -0.094623
#  Name: GarageType, dtype: float64)

# %%
import datawig

target_feature = "GarageType"

imputer = datawig.SimpleImputer(input_columns=['YearBuilt', 'OverallQual', 'BsmtQual'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
print(train['GarageFinish'].value_counts())
print(train.loc[train['GarageFinish'] == "Unf", 'SalePrice'].mean())
print(train.loc[train['GarageFinish'] == "RFn", 'SalePrice'].mean())
print(train.loc[train['GarageFinish'] == "Fin", 'SalePrice'].mean())
# Out:
# 1.0    605
# 2.0    422
# 3.0    352
# Name: GarageFinish, dtype: int64
# nan
# nan
# nan

# %%
conn = train.corr()

# %%
conn['GarageFinish'].sort_values(ascending = False)[:5],  conn['GarageFinish'].sort_values()[:5]
# Out:
# (GarageFinish    1.000000
#  YearBuilt       0.583538
#  GarageType      0.546514
#  BsmtQual        0.540791
#  OverallQual     0.519623
#  Name: GarageFinish, dtype: float64,
#  OverallCond     -0.210396
#  EnclosedPorch   -0.186538
#  KitchenAbvGr    -0.160634
#  ExterCond       -0.103933
#  LowQualFinSF    -0.063486
#  Name: GarageFinish, dtype: float64)

# %%
import datawig

target_feature = "GarageFinish"

imputer = datawig.SimpleImputer(input_columns=['YearBuilt', 'GarageType', 'BsmtQual', 'OverallQual'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
conn['GarageQual'].sort_values(ascending = False)[:5],  conn['GarageQual'].sort_values()[:5]
# Out:
# (GarageQual      1.000000
#  GarageCond      0.567022
#  LowQualFinSF    0.140504
#  OverallCond     0.115202
#  PoolArea        0.087346
#  Name: GarageQual, dtype: float64,
#  YearBuilt     -0.089181
#  Exterior2nd   -0.051345
#  MasVnrType    -0.048785
#  Exterior1st   -0.045182
#  BsmtQual      -0.044085
#  Name: GarageQual, dtype: float64)

# %%
import datawig

target_feature = "GarageQual"

imputer = datawig.SimpleImputer(input_columns=['GarageCond', 'LowQualFinSF'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
conn['GarageCond'].sort_values(ascending = False)[:5],  conn['GarageCond'].sort_values()[:5]
# Out:
# (GarageCond      1.000000
#  GarageQual      0.567022
#  PoolArea        0.111049
#  LowQualFinSF    0.069811
#  OverallCond     0.051477
#  Name: GarageCond, dtype: float64,
#  YearRemodAdd   -0.062753
#  KitchenQual    -0.045505
#  Exterior1st    -0.043733
#  YearBuilt      -0.043179
#  FullBath       -0.042375
#  Name: GarageCond, dtype: float64)

# %%
import datawig

target_feature = "GarageCond"

imputer = datawig.SimpleImputer(input_columns=['GarageQual', 'PoolArea'],
                                output_column=target_feature)
imputer.fit(train_df=train, num_epochs=50)

null_train = train[train[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(train)):
    if np.isnan(train[target_feature].iloc[i]) == True:
        train[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1
        
null_train = test[test[target_feature].isnull()]
null_imputed = imputer.predict(null_train)
imputed_train = pd.DataFrame(null_imputed)

n = 0
for i in range(len(test)):
    if np.isnan(test[target_feature].iloc[i]) == True:
        test[target_feature].iloc[i] = int(round(imputed_train[target_feature+"_imputed"].iloc[n]))
        n += 1

# %%
train['Sum of Exterior1st'] = train['Exterior1st'] + train['Exterior2nd']
test['Sum of Exterior1st'] = test['Exterior1st'] + test['Exterior2nd']

train = train.drop(['Exterior1st', 'Exterior2nd'], axis=1)
test = test.drop(['Exterior1st', 'Exterior2nd'], axis=1)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 66 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MSSubClass          1459 non-null   int64
#  1   MSZoning            1459 non-null   float64
#  2   LotFrontage         1459 non-null   float64
#  3   LotArea             1459 non-null   int64
#  4   LotShape            1459 non-null   int64
#  5   LandContour         1459 non-null   object
#  6   LotConfig           1459 non-null   object
#  7   LandSlope           1459 non-null   object
#  8   Neighborhood        1459 non-null   object
#  9   Condition1          1459 non-null   object
#  10  BldgType            1459 non-null   object
#  11  HouseStyle          1459 non-null   object
#  12  OverallQual         1459 non-null   int64
#  13  OverallCond         1459 non-null   int64
#  14  YearBuilt           1459 non-null   int64
# ...

# %% [markdown]
# ## 특성 설명

# %%
# def pool(x):
#   if x>0:
#     return 1
#   else:
#     return 0

# train['boolean Pool'] = train['PoolArea'].apply(pool)
# test['boolean Pool'] = test['PoolArea'].apply(pool)

# 효과 없음.

# %%
conn = train.corr()

# %%
train.loc[train['PoolArea'] == 0, 'SalePrice'].mean()
# Out:
# 180404.66345492084

# %%
train.loc[train['PoolArea'] > 0, 'SalePrice'].mean()
# Out:
# 288138.57142857136

# %%
conn['SalePrice']['PoolArea']
# Out:
# 0.0924035494918731

# %%
conn['SalePrice'].sort_values()[:20]
# Out:
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# MSSubClass      -0.084284
# OverallCond     -0.077856
# ExterCond       -0.045132
# YrSold          -0.028923
# LowQualFinSF    -0.025606
# MiscVal         -0.021190
# GarageCond      -0.018976
# BsmtHalfBath    -0.016844
# BsmtFinSF2      -0.011378
# BsmtFinType2     0.000076
# 3SsnPorch        0.044584
# MoSold           0.046432
# GarageQual       0.055203
# BsmtCond         0.088824
# PoolArea         0.092404
# ScreenPorch      0.111447
# MSZoning         0.154662
# BedroomAbvGr     0.168213
# Name: SalePrice, dtype: float64

# %%
conn['SalePrice'].sort_values(ascending = False)[:10]
# Out:
# SalePrice      1.000000
# OverallQual    0.790982
# GrLivArea      0.708624
# ExterQual      0.681183
# KitchenQual    0.664068
# BsmtQual       0.655823
# GarageArea     0.623431
# TotalBsmtSF    0.613581
# 1stFlrSF       0.605852
# FullBath       0.560664
# Name: SalePrice, dtype: float64

# %%
print(train.corr()['1stFlrSF']['TotalBsmtSF'])
# 1stFlrSF TotalBsmtSF 0.8195299750050339

train['Total Sum of 1sf and 2nd'] = train['1stFlrSF'] + train['TotalBsmtSF']
test['Total Sum of 1sf and 2nd'] = test['1stFlrSF'] + test['TotalBsmtSF']

train = train.drop(['1stFlrSF', 'TotalBsmtSF'], axis=1)
test = test.drop(['1stFlrSF', 'TotalBsmtSF'], axis=1)
# Out:
# 0.8195299750050339

# %%
# 각 컬럼별 BoxPlot
train.plot(kind='box', subplots=True, layout=(30, 3), figsize=(30, 50))
plt.show()

# %%
# for list1 in test.columns:
#   for list2 in test.columns:
#     if (list1 == list2):
#       break

#     if (conn[list1][list2] > 0.7):
#       print(list1 , list2 , conn[list1][list2])

# %%
from sklearn.preprocessing import LabelEncoder

train[train.columns[train.dtypes=='O']] = train[train.columns[train.dtypes=='O']].astype(str).apply(LabelEncoder().fit_transform)
test[test.columns[test.dtypes=='O']] = test[test.columns[test.dtypes=='O']].astype(str).apply(LabelEncoder().fit_transform)

# %%
for col in train.columns:
  train[col] = train[col].fillna(train[col].mean())

for col in test.columns:
  test[col] = test[col].fillna(test[col].mean())

# %%
import seaborn as sns
plt.subplots(figsize=(20,20))
sns.heatmap(train.corr(), mask=np.zeros_like(train.corr(), dtype=bool),
            square=True, annot=True, cmap='RdBu_r')
plt.show()

# %%
# # 학습 변수 선택
# # 문자열 변수, 결측치 포함 변수 제외 후 학습

features = test.columns

X = train[features]
Y = train['SalePrice']

# %%
train
# Out:
#       MSSubClass  MSZoning  ...  Sum of Exterior1st  Total Sum of 1sf and 2nd
# 0             60       3.0  ...            6.000000                      1712
# 1             20       3.0  ...            4.000000                      2524
# 2             60       3.0  ...            6.000000                      1840
# 3             70       3.0  ...            4.776065                      1717
# 4             60       3.0  ...            6.000000                      2290
# ...          ...       ...  ...                 ...                       ...
# 1455          60       3.0  ...            6.000000                      1906
# 1456          20       3.0  ...            4.000000                      3615
# 1457          70       3.0  ...            4.776065                      2340
# 1458          20       3.0  ...            4.000000                      2156
# 1459          20       3.0  ...            4.000000                      2512
#
# [1460 rows x 66 columns]

# %%
Y = np.log1p(Y)
Y = pd.DataFrame(Y)
Y
# Out:
#       SalePrice
# 0     12.247699
# 1     12.109016
# 2     12.317171
# 3     11.849405
# 4     12.429220
# ...         ...
# 1455  12.072547
# 1456  12.254868
# 1457  12.493133
# 1458  11.864469
# 1459  11.901590
#
# [1460 rows x 1 columns]

# %%
def kfold(model, train, scale = False):
    cv_accuracy = []
    cv = StratifiedKFold(n_splits=5)
    
    n_iter = 0
    
    for t, v in cv.split(train, train['SalePrice']):
        
        train_cv = train.iloc[t] # 훈련용
        val_cv = train.iloc[v] # 검증용 분리

        train_X = train_cv.drop('SalePrice', axis=1)
        train_y = train_cv['SalePrice']

        val_X = val_cv.drop('SalePrice', axis=1)
        val_y = val_cv['SalePrice']
            
        model.fit(train_X, train_y)
        score = mean_squared_error(val_y, model.predict(val_X))**0.5
        
        cv_accuracy.append(score)
        n_iter += 1
    return np.mean(cv_accuracy)

# %%
model_names=[
            #  RandomForestRegressor(),
            # KNeighborsRegressor(),
            # BaggingRegressor(),
            # GradientBoostingRegressor(),
            # XGBRegressor(),
            # LGBMRegressor(),             
            # AdaBoostRegressor(),
            # LinearRegression(),
            # Lasso(),
            # Ridge(),
            CatBoostRegressor(silent=True, learning_rate =0.03),
           CatBoostRegressor(silent=True, learning_rate =0.02),

            # NGBRegressor(),
            ]


for model in model_names:
    print(f'{type(model).__name__} score: {kfold(model, train)}')

# %%
X.shape, Y.shape
# Out:
# ((1460, 65), (1460, 1))

# %%
train.shape , test.shape
# Out:
# ((1460, 66), (1459, 65))

# %%
fes = test.columns

# %% [markdown]
# # optuna를 통한 하이퍼 파라메타 튜닝. -> 처음해보았는데 성능 별로.....

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(train[fes], train['SalePrice'], test_size=0.2, 
                                                      random_state=42, shuffle=False,  stratify=None)

# %%
def objective(trial):
    param = {
       "n_estimators" : trial.suggest_int('n_estimators', 500, 4000),
        'max_depth':trial.suggest_int('max_depth', 8, 16),
        'min_child_weight':trial.suggest_int('min_child_weight', 1, 300),
        'gamma':trial.suggest_int('gamma', 1, 3),
        'learning_rate': 0.01,
        'colsample_bytree':trial.suggest_discrete_uniform('colsample_bytree',0.5, 1, 0.1),
        'nthread' : -1,
        'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
        'subsample': trial.suggest_categorical('subsample', [0.6,0.7,0.8,1.0] ),
        'random_state': 42
    }
    
    model = XGBRegressor(**param)
    xgb_model = model.fit(X, Y, verbose=False)
    
    score = mean_squared_error(xgb_model.predict(X), Y, squared=False)
    
    return score

# %%
import lightgbm as lgb
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# %%
import optuna
study = optuna.create_study(sampler=optuna.samplers.RandomSampler(seed=0))
study.optimize(objective, n_trials=50)
study.best_params
# Out:
# [I 2022-02-18 08:16:01,991] A new study created in memory with name: no-name-e8bcfc4b-19d3-4810-b2be-4266a40d19e7
# [I 2022-02-18 08:16:20,502] Trial 0 finished with value: 0.17460242023810973 and parameters: {'n_estimators': 2421, 'max_depth': 14, 'min_child_weight': 181, 'gamma': 2, 'colsample_bytree': 0.7, 'lambda': 0.3833332156156664, 'alpha': 0.0562793204741517, 'subsample': 0.7}. Best is trial 0 with value: 0.17460242023810973.
# [I 2022-02-18 08:16:31,706] Trial 1 finished with value: 0.17183397873392428 and parameters: {'n_estimators': 2351, 'max_depth': 13, 'min_child_weight': 278, 'gamma': 1, 'colsample_bytree': 0.5, 'lambda': 0.001204685241203032, 'alpha': 2.1403233140986067, 'subsample': 0.8}. Best is trial 1 with value: 0.17183397873392428.
# ...

# %%
# # from sklearn.model_selection import train_test_split
# # from sklearn.ensemble import RandomForestClassifier
# from catboost import CatBoostRegressor
# model = LGBMRegressor(random_seed = 42, learning_rate = 0.1374211952274503,  n_estimators = 1026,
#                       num_leaves= 11,
#  max_bin= 97,
#  bagging_fraction= 0.5818553854713113,
#  bagging_freq= 6,
#  feature_fraction= 0.6193007567311601,
#  min_data_in_leaf= 16,
#  min_sum_hessian_in_leaf= 2 )
# model.fit(X, Y)
# pred = model.predict(test[features])

# %%
# pp =  {'n_estimators': 1246, 'max_depth': 12, 'min_child_weight': 8, 'gamma': 1,
#      'colsample_bytree': 0.7, 'lambda': 0.03138194965443052, 'alpha': 0.07149928477357939, 'subsample': 0.8}

# %%
# model_xgb = XGBRegressor(**pp)
# model_xgb.fit(X, Y)
# pred_xgb = model_xgb.predict(test[features])

# %%
from lightgbm import LGBMRegressor
model_lgbm = LGBMRegressor()
model_lgbm.fit(X, Y)
pred_lgbm = model_lgbm.predict(test[features])

# %%
from catboost import CatBoostRegressor
model_cb = CatBoostRegressor(learning_rate=0.02)
model_cb.fit(X, Y)
pred_cb = model_cb.predict(test[features])

# %%
pred_lgbm = np.expm1(pred_lgbm)
pred_ccbb = np.expm1(pred_cb)

# %%
pred_ex =pred_ccbb * 0.8 + pred_lgbm * 0.2

# %%
submission['SalePrice'] = (pred_ex)

# %%
submission
# Out:
#         Id      SalePrice
# 0     1461  129325.399842
# 1     1462  161346.209116
# 2     1463  184571.804985
# 3     1464  190535.530773
# 4     1465  188049.582221
# ...    ...            ...
# 1454  2915   84079.781373
# 1455  2916   83075.523167
# 1456  2917  155690.974361
# 1457  2918  118720.113335
# 1458  2919  210790.538483
#
# [1459 rows x 2 columns]

# %%
pjt.submit(submission)
# Out:
# 파일을 저장하였습니다. 파일명: submission-08-28-39.csv
# 제출 여부 :success
# 오늘 제출 횟수 : 25
# 제출 결과:0.12456195231995175

# %% [markdown]
# # 이제부터 자유롭게 분석, 예측을 진행하시면 됩니다.
